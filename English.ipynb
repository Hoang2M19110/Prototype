# %%
# !pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 51.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 30.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 94.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 78.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 30.7 MB/s eta 0:00:00
# ...

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration
from transformers import GPT2Tokenizer, GPT2LMHeadModel , pipeline
import time, torch

# %%
text = """
iPhone is a line of smartphones produced by Apple Inc. that use Apple's own iOS mobile operating system. The first-generation iPhone was announced by then-Apple CEO Steve Jobs on January 9, 2007. Since then, Apple has annually released new iPhone models and iOS updates. As of November 1, 2018, more than 2.2 billion iPhones had been sold. As of 2022, the iPhone accounts for 15.6% of global smartphone market share.[3]

The iPhone was the first mobile phone to use multi-touch technology.[4] Since the iPhone's launch, it has gained larger screen sizes, video-recording, waterproofing, and many accessibility features. Up to the iPhone 8 and 8 Plus, iPhones had a single button on the front panel with the Touch ID fingerprint sensor. Since the iPhone X, iPhone models have switched to a nearly bezel-less front screen design with Face ID facial recognition, and app switching activated by gestures. Touch ID is still used for the budget iPhone SE series.
"""

or_len = len(text)

# %%
def summarize_text(text, summary_length_percent):
    # Ensure the percentage is between 1 and 100
    if summary_length_percent < 1 or summary_length_percent > 100:
        raise ValueError("Summary length percent must be between 1 and 100")

    input_length = len(text.split())  # Calculate the number of words in the input text
    max_length_value = int(input_length * ((summary_length_percent + 10) / 100))  # Calculate max length as a percentage of input length
    min_length_value = int(input_length * ((summary_length_percent - 10) / 100))  # Set the min length as half of the max length for variability

    # Generate the summary
    summary = summarizer(
        text,
        max_length=max_length_value,
        min_length=min_length_value,
        length_penalty=2.0,
        num_beams=4,
        early_stopping=True
    )
    return summary[0]['summary_text']

# %%
summarizer = pipeline("summarization", model="google/flan-t5-small")

# %%
def summarize_text(text, summary_length_percent):
    # Ensure the percentage is between 1 and 100
    if summary_length_percent < 1 or summary_length_percent > 100:
        raise ValueError("Summary length percent must be between 1 and 100")

    input_length = len(text.split())  # Calculate the number of words in the input text
    max_length_value = int(input_length * ((summary_length_percent + 10) / 100))  # Calculate max length as a percentage of input length
    min_length_value = int(input_length * ((summary_length_percent - 10) / 100))  # Set the min length as half of the max length for variability

    # Generate the summary
    summary = summarizer(
        text,
        max_length=max_length_value,
        min_length=min_length_value,
        length_penalty=2.0,
        num_beams=4,
        early_stopping=True
    )
    return summary[0]['summary_text']

# %%
time_start = time.time()
# Summarize at different levels
summary_25_percent = summarize_text(text, 25)  # Summary at 25% of original text length
time_end = time.time()

# Print the summaries
print("25% Summary:\n", summary_25_percent)
print(f"Execution Time: {time_end - time_start} seconds")
# Out:
# 25% Summary:
#  iPhone is a line of smartphones produced by Apple Inc. that use Apple's own iOS mobile operating system.
# Execution Time: 2.5143003463745117 seconds

# %%
time_start = time.time()
# Summarize at different levels
summary_25_percent = summarize_text(text, 50)  # Summary at 25% of original text length
time_end = time.time()

# Print the summaries
print("50% Summary:\n", summary_25_percent)
print(f"Execution Time: {time_end - time_start} seconds")
# Out:
# 50% Summary:
#  iPhone is a line of smartphones produced by Apple Inc. that use Apple's own iOS mobile operating system. The first-generation iPhone was announced by then-Apple CEO Steve Jobs on January 9, 2007. Since then, Apple has annually released new iPhone models and iOS updates. As of November 1, 2018, more than 2.2 billion iPhones had been sold.
# Execution Time: 4.34714937210083 seconds

# %%
time_start = time.time()
# Summarize at different levels
summary_25_percent = summarize_text(text, 75)  # Summary at 25% of original text length
time_end = time.time()

# Print the summaries
print("75% Summary:\n", summary_25_percent)
print(f"Execution Time: {time_end - time_start} seconds")
# Out:
# 75% Summary:
#  iPhone is a line of smartphones produced by Apple Inc. that use Apple's own iOS mobile operating system.The first-generation iPhone was announced by then-Apple CEO Steve Jobs on January 9, 2007. Since then, Apple has annually released new iPhone models and iOS updates. As of November 1, 2018, more than 2.2 billion iPhones had been sold. The iPhone was the first mobile phone to use multi-touch technology. Since the iPhone X, iPhone models have switched to a nearly bezel-less front screen design with Face ID facial recognition, and app switching activated by gestures.
# Execution Time: 7.803235054016113 seconds
